# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [16, 8]

fortune = np.ones(100) * 100
people_id = range(100)

people_group1 = people_id[:10]
fortune_group1 = fortune[:10]
people_group2 = people_id[10:]
fortune_group2 = fortune[10:]
df1 = pd.DataFrame({"id": people_group1, "fortune": fortune_group1})
df2 = pd.DataFrame({"id": people_group2, "fortune": fortune_group2})
plt.bar(people_group1, fortune_group1, color="r")
plt.bar(people_group2, fortune_group2, color='b')
plt.show()

p = np.ones(100) * 1/(1.02*10+1*90)
for i in range(10):
    p[i] = 1/(1.02*10+1*90) * 1.02



days = 35*365
for i in range(days):
    fortune = fortune - np.ones(100)
    receivers = np.random.choice(people_id, 100, p=p)
    unique, counts = np.unique(receivers, return_counts=True)
    gains = zip(unique, counts)
    for (idx, gain) in gains:
        fortune[idx] += gain

print(fortune)

ind = np.argsort(fortune)[::-1]
rank = np.argsort(ind)

people_group1 = rank[:10]
fortune_group1 = fortune[:10]
people_group2 = rank[10:]
fortune_group2 = fortune[10:]
df1 = pd.DataFrame({"id": people_group1, "fortune": fortune_group1})
df2 = pd.DataFrame({"id": people_group2, "fortune": fortune_group2})
plt.bar(people_group1, fortune_group1, color="r")
plt.bar(people_group2, fortune_group2, color='b')
plt.show()
# Out:
# [ 428.  174.  380.  271.   74.  505.  409.  131.   35.  619.   73. -134.
#   125.    7.   96.   75.  -56.  -98.   63.  123.  107.  261. -119.  102.
#   203.   62.   82.   45.  -80.  148.   21.  187.  -24.  246.  269.  -57.
#   187.  219.  -17.  109.  147.  -76.  105.  107.  193.   81.   60.  137.
#   145.   -7.   57.  -24.  143.  235.  -61.  -43.   43. -195.   -4.  116.
#   211.   81.   93.   71.  -26.    7.  218.  218. -106.   83.  114.  144.
#    -6.   52.  203.  162.  -72.   20.   66.   97.  102.  143.  168.   28.
#    38.  -38.  397.   91.  235.  189.  266.  162.  -68.   74. -162.   32.
#    63.  -45.   75.  210.]

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = [16, 8]

fortune = np.ones(100) * 100
people_id = range(100)

people_group1 = people_id[:10]
fortune_group1 = fortune[:10]
people_group2 = people_id[10:]
fortune_group2 = fortune[10:]
df1 = pd.DataFrame({"id": people_group1, "fortune": fortune_group1})
df2 = pd.DataFrame({"id": people_group2, "fortune": fortune_group2})
plt.bar(people_group1, fortune_group1, color="r")
plt.bar(people_group2, fortune_group2, color='b')
plt.show()

p = np.ones(100) * 1/(1.00*10+1*90)
spend = np.ones(100)
spend[:10] = spend[:10]*0.98

days = 35*365
for i in range(days):
    fortune = fortune - spend
    receivers = np.random.choice(people_id, 100, p=p)
    unique, counts = np.unique(receivers, return_counts=True)
    gains = zip(unique, counts)
    for (idx, gain) in gains:
        fortune[idx] += gain

print(fortune)

ind = np.argsort(fortune)[::-1]
rank = np.argsort(ind)

people_group1 = rank[:10]
fortune_group1 = fortune[:10]
people_group2 = rank[10:]
fortune_group2 = fortune[10:]
df1 = pd.DataFrame({"id": people_group1, "fortune": fortune_group1})
df2 = pd.DataFrame({"id": people_group2, "fortune": fortune_group2})
plt.bar(people_group1, fortune_group1, color="r")
plt.bar(people_group2, fortune_group2, color='b')
plt.show()
# Out:
# [ 465.5  412.5  245.5  211.5  276.5  310.5  184.5  356.5  256.5  393.5
#    85.   202.   443.    62.    10.    22.   110.   272.   -11.   107.
#   215.   -63.   162.   164.    66.   230.    89.   156.    22.   131.
#     8.   148.    85.   230.   -81.    90.   206.   231.     1.     7.
#   112.   295.   255.   107.  -231.   -33.   -66.   144.   270.   171.
#    69.   215.   173.   136.    92.    49.   238.    38.   164.   293.
#    22.   -43.   290.    43.   -12.   204.    97.   -65.    72.   192.
#   312.    15.    81.     2.   176.   218.    61.   -41.    25.    76.
#    -8.   -36.    79.   167.    75.   168.   -73.   -24.   204.   166.
#   121.  -174.   123.    80.    97.    95.   238.   170.   104.   255. ]
